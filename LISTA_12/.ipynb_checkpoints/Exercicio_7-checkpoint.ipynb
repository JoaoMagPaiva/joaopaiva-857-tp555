# %%
import tensorflow as tf
import numpy as np
from tensorboard import notebook
from sklearn.model_selection import train_test_split

# %%
# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
    
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
reset_graph()

n_inputs = 28*28 # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation=="relu":
            return tf.nn.relu(z)
        else:
            return z

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")
    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")
    
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 400
batch_size = 50

acc_test_hist = 0.1
contador = 0

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
        if (acc_test > acc_test_hist):
            acc_test_hist = acc_test
            save_path = saver.save(sess, "./my_model_final_ex7.ckpt")
            contador = 0
            
        else:
            
            contador = contador + 1
            print("Contagem: " , contador)
            
        if(contador == 50):
                break;
# Out:
# 0 Train accuracy: 0.98 Test accuracy: 0.9124
# 1 Train accuracy: 0.92 Test accuracy: 0.934
# 2 Train accuracy: 0.98 Test accuracy: 0.946
# 3 Train accuracy: 0.98 Test accuracy: 0.9524
# 4 Train accuracy: 0.92 Test accuracy: 0.9556
# 5 Train accuracy: 0.94 Test accuracy: 0.9572
# 6 Train accuracy: 0.98 Test accuracy: 0.9616
# 7 Train accuracy: 0.98 Test accuracy: 0.9626
# 8 Train accuracy: 0.94 Test accuracy: 0.9646
# 9 Train accuracy: 1.0 Test accuracy: 0.9644
# Contagem:  1
# 10 Train accuracy: 0.96 Test accuracy: 0.9664
# 11 Train accuracy: 1.0 Test accuracy: 0.968
# 12 Train accuracy: 0.96 Test accuracy: 0.9712
# 13 Train accuracy: 1.0 Test accuracy: 0.9712
# Contagem:  1
# 14 Train accuracy: 1.0 Test accuracy: 0.9712
# Contagem:  2
# 15 Train accuracy: 0.98 Test accuracy: 0.9738
# 16 Train accuracy: 1.0 Test accuracy: 0.9738
# Contagem:  1
# 17 Train accuracy: 1.0 Test accuracy: 0.9734
# Contagem:  2
# 18 Train accuracy: 0.92 Test accuracy: 0.9752
# 19 Train accuracy: 1.0 Test accuracy: 0.9752
# Contagem:  1
# 20 Train accuracy: 1.0 Test accuracy: 0.9762
# 21 Train accuracy: 0.98 Test accuracy: 0.9762
# Contagem:  1
# 22 Train accuracy: 1.0 Test accuracy: 0.9766
# 23 Train accuracy: 1.0 Test accuracy: 0.976
# Contagem:  1
# 24 Train accuracy: 0.98 Test accuracy: 0.9778
# 25 Train accuracy: 1.0 Test accuracy: 0.978
# 26 Train accuracy: 1.0 Test accuracy: 0.978
# Contagem:  1
# 27 Train accuracy: 0.98 Test accuracy: 0.9738
# Contagem:  2
# 28 Train accuracy: 1.0 Test accuracy: 0.9792
# 29 Train accuracy: 0.98 Test accuracy: 0.976
# Contagem:  1
# 30 Train accuracy: 1.0 Test accuracy: 0.9768
# Contagem:  2
# 31 Train accuracy: 1.0 Test accuracy: 0.9774
# Contagem:  3
# 32 Train accuracy: 0.98 Test accuracy: 0.978
# Contagem:  4
# 33 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  5
# 34 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  6
# 35 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  7
# 36 Train accuracy: 1.0 Test accuracy: 0.978
# Contagem:  8
# 37 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  9
# 38 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  10
# 39 Train accuracy: 1.0 Test accuracy: 0.977
# Contagem:  11
# 40 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  12
# 41 Train accuracy: 0.98 Test accuracy: 0.9796
# 42 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  1
# 43 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  2
# 44 Train accuracy: 1.0 Test accuracy: 0.978
# Contagem:  3
# 45 Train accuracy: 0.98 Test accuracy: 0.9788
# Contagem:  4
# 46 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  5
# 47 Train accuracy: 1.0 Test accuracy: 0.9782
# Contagem:  6
# 48 Train accuracy: 0.96 Test accuracy: 0.979
# Contagem:  7
# 49 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  8
# 50 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  9
# 51 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  10
# 52 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  11
# 53 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  12
# 54 Train accuracy: 1.0 Test accuracy: 0.978
# Contagem:  13
# 55 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  14
# 56 Train accuracy: 1.0 Test accuracy: 0.9794
# Contagem:  15
# 57 Train accuracy: 1.0 Test accuracy: 0.9796
# Contagem:  16
# 58 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  17
# 59 Train accuracy: 1.0 Test accuracy: 0.98
# 60 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  1
# 61 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  2
# 62 Train accuracy: 1.0 Test accuracy: 0.9794
# Contagem:  3
# 63 Train accuracy: 1.0 Test accuracy: 0.978
# Contagem:  4
# 64 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  5
# 65 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  6
# 66 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  7
# 67 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  8
# 68 Train accuracy: 1.0 Test accuracy: 0.9796
# Contagem:  9
# 69 Train accuracy: 1.0 Test accuracy: 0.9782
# Contagem:  10
# 70 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  11
# 71 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  12
# 72 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  13
# 73 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  14
# 74 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  15
# 75 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  16
# 76 Train accuracy: 1.0 Test accuracy: 0.9794
# Contagem:  17
# 77 Train accuracy: 1.0 Test accuracy: 0.9782
# Contagem:  18
# 78 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  19
# 79 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  20
# 80 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  21
# 81 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  22
# 82 Train accuracy: 1.0 Test accuracy: 0.978
# Contagem:  23
# 83 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  24
# 84 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  25
# 85 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  26
# 86 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  27
# 87 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  28
# 88 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  29
# 89 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  30
# 90 Train accuracy: 1.0 Test accuracy: 0.9782
# Contagem:  31
# 91 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  32
# 92 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  33
# 93 Train accuracy: 1.0 Test accuracy: 0.9794
# Contagem:  34
# 94 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  35
# 95 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  36
# 96 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  37
# 97 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  38
# 98 Train accuracy: 1.0 Test accuracy: 0.9788
# Contagem:  39
# 99 Train accuracy: 1.0 Test accuracy: 0.9784
# Contagem:  40
# 100 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  41
# 101 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  42
# 102 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  43
# 103 Train accuracy: 1.0 Test accuracy: 0.9794
# Contagem:  44
# 104 Train accuracy: 1.0 Test accuracy: 0.979
# Contagem:  45
# 105 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  46
# 106 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  47
# 107 Train accuracy: 1.0 Test accuracy: 0.9792
# Contagem:  48
# 108 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  49
# 109 Train accuracy: 1.0 Test accuracy: 0.9786
# Contagem:  50

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final_ex7.ckpt") # or better, use save_path
    X_new_scaled = X_test[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final_ex7.ckpt

# %%
print("Predicted classes:", y_pred)
print("Actual classes:   ", y_test[:20])
# Out:
# Predicted classes: [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# Actual classes:    [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
