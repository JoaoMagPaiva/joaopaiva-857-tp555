# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = np.random.uniform(0.0, 1.0, 1000)
w = np.random.normal(0.0, 1.0, 1000)

y = 1.2 + 2.3*x + 10*w

plt.title('Grafico')
plt.plot(x, y, color='b')
plt.xlabel('X')
plt.ylabel('Y')

plt.savefig('Grafico.png')
